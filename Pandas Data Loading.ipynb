# %%
# !pip install mysql.connector kaggle pandas

# %%
import pandas as pd
import zipfile
import os

# %%
# !kaggle datasets download -d amanbarthwal/steam-store-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/amanbarthwal/steam-store-data
# License(s): MIT
# ...
#   0% 0.00/5.83M [00:00<?, ?B/s]
# 100% 5.83M/5.83M [00:00<00:00, 68.3MB/s]

# %%
with zipfile.ZipFile("steam-store-data.zip", "r") as file:
  file.extractall(os.getcwd())

# %% [markdown]
# ## CSV File

# %%
csv_df = pd.read_csv("steam-games.csv")
csv_df.head()
# Out:
#     app_id                             title  release_date  \
# 0      730                  Counter-Strike 2  21 Aug, 2012
# 1      570                            Dota 2   9 Jul, 2013
# 2  2215430  Ghost of Tsushima DIRECTOR'S CUT  16 May, 2024
# 3  1245620                        ELDEN RING  24 Feb, 2022
# 4  1085660                         Destiny 2   1 Oct, 2019
#
#                             genres  \
# 0             Action, Free to Play
# 1   Action, Strategy, Free to Play
# 2                Action, Adventure
# 3                      Action, RPG
# 4  Action, Adventure, Free to Play
#
#                                           categories  \
# 0  Cross-Platform Multiplayer, Steam Trading Card...
# 1  Steam Trading Cards, Steam Workshop, SteamVR C...
# 2  Single-player, Online Co-op, Steam Achievement...
# 3  Single-player, Online PvP, Online Co-op, Steam...
# 4  Single-player, Online PvP, Online Co-op, Steam...
#
# ...

# %% [markdown]
# ## Excel File

# %%
csv_df.to_excel("steam-games.xlsx")

# %%
excel_df = pd.read_excel("steam-games.xlsx")
excel_df.head()
# Out:
#    Unnamed: 0   app_id                             title  release_date  \
# 0           0      730                  Counter-Strike 2  21 Aug, 2012
# 1           1      570                            Dota 2   9 Jul, 2013
# 2           2  2215430  Ghost of Tsushima DIRECTOR'S CUT  16 May, 2024
# 3           3  1245620                        ELDEN RING  24 Feb, 2022
# 4           4  1085660                         Destiny 2   1 Oct, 2019
#
#                             genres  \
# 0             Action, Free to Play
# 1   Action, Strategy, Free to Play
# 2                Action, Adventure
# 3                      Action, RPG
# 4  Action, Adventure, Free to Play
#
#                                           categories  \
# 0  Cross-Platform Multiplayer, Steam Trading Card...
# 1  Steam Trading Cards, Steam Workshop, SteamVR C...
# 2  Single-player, Online Co-op, Steam Achievement...
# 3  Single-player, Online PvP, Online Co-op, Steam...
# ...

# %% [markdown]
# ## JSON File

# %%
excel_df.to_json("steam-games.json")

# %%
json_df = pd.read_json("steam-games.json")
json_df.head()
# Out:
#    Unnamed: 0   app_id                             title  release_date  \
# 0           0      730                  Counter-Strike 2  21 Aug, 2012
# 1           1      570                            Dota 2   9 Jul, 2013
# 2           2  2215430  Ghost of Tsushima DIRECTOR'S CUT  16 May, 2024
# 3           3  1245620                        ELDEN RING  24 Feb, 2022
# 4           4  1085660                         Destiny 2   1 Oct, 2019
#
#                             genres  \
# 0             Action, Free to Play
# 1   Action, Strategy, Free to Play
# 2                Action, Adventure
# 3                      Action, RPG
# 4  Action, Adventure, Free to Play
#
#                                           categories  \
# 0  Cross-Platform Multiplayer, Steam Trading Card...
# 1  Steam Trading Cards, Steam Workshop, SteamVR C...
# 2  Single-player, Online Co-op, Steam Achievement...
# 3  Single-player, Online PvP, Online Co-op, Steam...
# ...

# %% [markdown]
# ## Load SQL Data

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="imdb"
)

query = "SELECT * FROM imdb"

sql_df = pd.read_sql(query, conn)
sql_df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9448\710501743.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_df = pd.read_sql(query, conn)
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# ...

# %% [markdown]
# ## Load HTML

# %%
html_df = pd.read_html("https://en.wikipedia.org/wiki/Donald_Trump")[0]

# %%
html_df.head()
# Out:
#                                     Donald Trump  \
# 0                        Official portrait, 2017
# 1                                            NaN
# 2            45th President of the United States
# 3  In office January 20, 2017 – January 20, 2021
# 4                                 Vice President
#
#                                   Donald Trump.1
# 0                        Official portrait, 2017
# 1                                            NaN
# 2            45th President of the United States
# 3  In office January 20, 2017 – January 20, 2021
# 4                                     Mike Pence

# %%
# %who_ls DataFrame
# Out:
# ['csv_df', 'excel_df', 'json_df', 'sql_df']
