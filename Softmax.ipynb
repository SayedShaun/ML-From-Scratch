# %% [markdown]
# ### SoftMax

# %% [markdown]
# ![IMG_20240113_164521 (1) (Custom).jpg](<attachment:IMG_20240113_164521 (1) (Custom).jpg>)

# %% [markdown]
# ![IMG_20240113_164539 (Custom).jpg](<attachment:IMG_20240113_164539 (Custom).jpg>)
